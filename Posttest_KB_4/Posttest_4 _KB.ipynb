# %% [markdown]
# # POSTTEST 4 KB
#
# - NAMA : NUR YAHYA
# - NIM : 2109106073

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## MEMBAGI DATASET MENJADI TRAIN SET DAN TEST SET

# %%
df = pd.read_csv("all_perth_house.csv")


X = df.drop(columns='PRICE') #feature
Y = df.loc[:, 'PRICE'] #target

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

# %%
print('X Train : ' , X_train.shape)
print('X Test : ' , X_test.shape)
print('Y Train : ' , Y_train.shape)
print('Y Test : ' , Y_test.shape)
# Out:
# X Train :  (23559, 18)
# X Test :  (10097, 18)
# Y Train :  (23559,)
# Y Test :  (10097,)

# %% [markdown]
# ## NORMALISASI DENGAN MIN MAX SCALER

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

mm = MinMaxScaler()
mm.fit(X_train[['LAND_AREA']])
X_train_normalized = mm.transform(X_train[['LAND_AREA']])
X_train_normalized
# Out:
# array([[0.00110708],
#        [0.00377727],
#        [0.00073405],
#        ...,
#        [0.00044803],
#        [0.00063305],
#        [0.00042503]])

# %% [markdown]
# ## STANDARISASI DENGAN STANDARD SCALER

# %%
ss = StandardScaler()

X_train_scaled = ss.fit_transform(X_train[['FLOOR_AREA']])
X_train_scaled
# Out:
# array([[-0.34992629],
#        [ 2.56142722],
#        [-0.36378987],
#        ...,
#        [ 0.38484389],
#        [-0.25288117],
#        [ 0.91166024]])

# %% [markdown]
# ## DATA CLEANING PADA DATA NULL
#
# * DATA SEBELUM DI FILL DENGAN NILAI MEDIAN

# %%
from sklearn.impute import SimpleImputer
df.isna().sum()
# Out:
# ADDRESS                 0
# SUBURB                  0
# PRICE                   0
# BEDROOMS                0
# BATHROOMS               0
# GARAGE               2478
# LAND_AREA               0
# FLOOR_AREA              0
# BUILD_YEAR           3155
# CBD_DIST                0
# NEAREST_STN             0
# NEAREST_STN_DIST        0
# DATE_SOLD               0
# POSTCODE                0
# LATITUDE                0
# LONGITUDE               0
# NEAREST_SCH             0
# NEAREST_SCH_DIST        0
# NEAREST_SCH_RANK    10952
# dtype: int64

# %%
df.GARAGE.fillna(df.GARAGE.median(), inplace=True)
df
# Out:
#                   ADDRESS           SUBURB    PRICE  BEDROOMS  BATHROOMS  \
# 0           1 Acorn Place       South Lake   565000         4          2
# 1             1 Addis Way            Wandi   365000         3          2
# 2         1 Ainsley Court          Camillo   287000         3          1
# 3         1 Albert Street         Bellevue   255000         2          1
# 4            1 Aman Place        Lockridge   325000         4          1
# ...                   ...              ...      ...       ...        ...
# 33651      9C Gold Street  South Fremantle  1040000         4          3
# 33652      9C Pycombe Way      Westminster   410000         3          2
# 33653      9D Pycombe Way      Westminster   427000         3          2
# 33654     9D Shalford Way       Girrawheen   295000         3          1
# 33655  9E Margaret Street          Midland   295000         3          1
#
#        GARAGE  LAND_AREA  FLOOR_AREA  BUILD_YEAR  CBD_DIST  \
# ...

# %% [markdown]
# * DATASET PADA ATRIBUT GARAGE SETELAH DIISI DENGAN NILAI MEDIAN
#
#
# menggunakan median atau nilai tengah karena merupakan satu ukuran pengukuran data
# dan mungkin cocok diterapkan untuk mengganti nilai dari garasi yang null

# %%
df.isna().sum()
# Out:
# ADDRESS                 0
# SUBURB                  0
# PRICE                   0
# BEDROOMS                0
# BATHROOMS               0
# GARAGE                  0
# LAND_AREA               0
# FLOOR_AREA              0
# BUILD_YEAR           3155
# CBD_DIST                0
# NEAREST_STN             0
# NEAREST_STN_DIST        0
# DATE_SOLD               0
# POSTCODE                0
# LATITUDE                0
# LONGITUDE               0
# NEAREST_SCH             0
# NEAREST_SCH_DIST        0
# NEAREST_SCH_RANK    10952
# dtype: int64

# %% [markdown]
# ## MENANGANI NILAI DUPLIKAT PADA DATASET
#
#
# * Ada 7 data duplikat

# %%
df.duplicated().sum()
# Out:
# 7

# %%
df.drop_duplicates(inplace = True)

df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## MENGGANTI NILAI PADA ATRIBUT

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder

ordinal = OrdinalEncoder()
onehot = OneHotEncoder(sparse= False)

df['BEDROOMS'] = ordinal.fit_transform(df[['BEDROOMS']])

# %%
df
# Out:
#                   ADDRESS           SUBURB    PRICE  BEDROOMS  BATHROOMS  \
# 0           1 Acorn Place       South Lake   565000       3.0          2
# 1             1 Addis Way            Wandi   365000       2.0          2
# 2         1 Ainsley Court          Camillo   287000       2.0          1
# 3         1 Albert Street         Bellevue   255000       1.0          1
# 4            1 Aman Place        Lockridge   325000       3.0          1
# ...                   ...              ...      ...       ...        ...
# 33651      9C Gold Street  South Fremantle  1040000       3.0          3
# 33652      9C Pycombe Way      Westminster   410000       2.0          2
# 33653      9D Pycombe Way      Westminster   427000       2.0          2
# 33654     9D Shalford Way       Girrawheen   295000       2.0          1
# 33655  9E Margaret Street          Midland   295000       2.0          1
#
#        GARAGE  LAND_AREA  FLOOR_AREA  BUILD_YEAR  CBD_DIST  \
# ...

# %% [markdown]
# ## ONE HOT ENCODING PADA DATASET

# %%
df['BATHROOMS'] = onehot.fit_transform(df[['BATHROOMS']])
# Out:
# C:\Users\Yha\B1-21\Yahya_073\lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
df
# Out:
#                   ADDRESS           SUBURB    PRICE  BEDROOMS  BATHROOMS  \
# 0           1 Acorn Place       South Lake   565000       3.0        0.0
# 1             1 Addis Way            Wandi   365000       2.0        0.0
# 2         1 Ainsley Court          Camillo   287000       2.0        1.0
# 3         1 Albert Street         Bellevue   255000       1.0        1.0
# 4            1 Aman Place        Lockridge   325000       3.0        1.0
# ...                   ...              ...      ...       ...        ...
# 33651      9C Gold Street  South Fremantle  1040000       3.0        0.0
# 33652      9C Pycombe Way      Westminster   410000       2.0        0.0
# 33653      9D Pycombe Way      Westminster   427000       2.0        0.0
# 33654     9D Shalford Way       Girrawheen   295000       2.0        1.0
# 33655  9E Margaret Street          Midland   295000       2.0        1.0
#
#        GARAGE  LAND_AREA  FLOOR_AREA  BUILD_YEAR  CBD_DIST  \
# ...
